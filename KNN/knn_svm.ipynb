# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("iphone_purchase_records.csv")
df.head(10)
# Out:
#    Gender  Age  Salary  Purchase Iphone
# 0    Male   19   19000                0
# 1    Male   35   20000                0
# 2  Female   26   43000                0
# 3  Female   27   57000                0
# 4    Male   19   76000                0
# 5    Male   27   58000                0
# 6  Female   27   84000                0
# 7  Female   32  150000                1
# 8    Male   25   33000                0
# 9  Female   35   65000                0

# %%
df.describe()
# Out:
#               Age         Salary  Purchase Iphone
# count  400.000000     400.000000       400.000000
# mean    37.655000   69742.500000         0.357500
# std     10.482877   34096.960282         0.479864
# min     18.000000   15000.000000         0.000000
# 25%     29.750000   43000.000000         0.000000
# 50%     37.000000   70000.000000         0.000000
# 75%     46.000000   88000.000000         1.000000
# max     60.000000  150000.000000         1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           400 non-null    object
#  1   Age              400 non-null    int64
#  2   Salary           400 non-null    int64
#  3   Purchase Iphone  400 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 12.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df["Gender"] = label_encoder.fit_transform(df["Gender"])
print(df)
# Out:
#      Gender  Age  Salary  Purchase Iphone
# 0         1   19   19000                0
# 1         1   35   20000                0
# 2         0   26   43000                0
# 3         0   27   57000                0
# 4         1   19   76000                0
# ..      ...  ...     ...              ...
# 395       0   46   41000                1
# 396       1   51   23000                1
# 397       0   50   20000                1
# 398       1   36   33000                0
# 399       0   49   36000                1
#
# [400 rows x 4 columns]

# %%
x = df[['Gender', 'Age', 'Salary']]
y = df['Purchase Iphone']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model = KNeighborsClassifier(n_neighbors=6)
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
predict = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.825

# %%
print(classification_report(y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.98      0.88        51
#            1       0.94      0.55      0.70        29
#
#     accuracy                           0.82        80
#    macro avg       0.87      0.77      0.79        80
# weighted avg       0.85      0.82      0.81        80

# %% [markdown]
# # SVM

# %%
# SVM_MODEL Import:

from sklearn.svm import SVC

# %%
model_1 = SVC()
model_1.fit(x_train,y_train)
# Out:
# SVC()

# %%
# Testing Accuracy
model_1.score(x_train,y_train)
# Out:
# 0.771875

# %%
predict = model_1.predict(x_test)

# %%
new_data = np.array([[0, 26, 43000]])

# Predict
prediction = model_1.predict(new_data)

print("Prediction:", prediction)
# Out:
# Prediction: [0]
# C:\Users\sheenstin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
# parameter check
svm1_model=SVC(C=10)
svm1_model.fit(x_train,y_train)
# Out:
# SVC(C=10)

# %%
# Training Accuracy Test Data
svm1_model.score(x_test,y_test)
# Out:
# 0.775

# %%
print(classification_report(y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.96      0.84        51
#            1       0.86      0.41      0.56        29
#
#     accuracy                           0.76        80
#    macro avg       0.80      0.69      0.70        80
# weighted avg       0.78      0.76      0.74        80
